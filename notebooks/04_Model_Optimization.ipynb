# %% [markdown]
# # Model Optimization
# This notebook implements hyperparameter tuning and model optimization.

# %%
import warnings
warnings.filterwarnings('ignore')
import os, pandas as pd, numpy as np
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score
import lightgbm as lgb, xgboost as xgb
import matplotlib.pyplot as plt
from scripts.config import RAW_DATA_DIR, FEATURE_CONFIG, LGBM_PARAMS, XGB_PARAMS, HYPERPARAM_GRID
from scripts.generate_sample_data import generate_sample_dataset
from scripts.data_loader import load_csv, split_data, build_preprocessor
